# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import sqlite3

# Plot settings
plt.style.use("default")
sns.set_theme(style="whitegrid")

# Display all columns
pd.set_option("display.max_columns", None)

# %%
conn = sqlite3.connect("../database/credit_risk.db")

# %%
df = pd.read_sql(
    "SELECT * FROM credit_data",
    conn
)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2       3913       3102        689          0          0
# 1      0      2       2682       1725       2682       3272       3455
# 2      0      0      29239      14027      13559      14331      14948
# 3      0      0      46990      48233      49291      28314      28959
# 4      0      0       8617       5670      35835      20940      19146
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
plt.figure(figsize=(12,5))

sns.heatmap(
    df.isnull(),
    cbar=False
)

plt.title("Missing Values")
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='str')

# %%
df.rename(
    columns={
        "default payment next month":"DEFAULT"
    },
    inplace=True
)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'DEFAULT'],
#       dtype='str')

# %%
df["DEFAULT"].value_counts()
# Out:
# DEFAULT
# 0    23364
# 1     6636
# Name: count, dtype: int64

# %%
df["DEFAULT"].value_counts()
# Out:
# DEFAULT
# 0    23364
# 1     6636
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x="DEFAULT",
    data=df
)

plt.title("Class Distribution of Default Class")
plt.show()

# %%
default_rate = (
    df["DEFAULT"].mean()
    * 100
)

print(
    f"Default Rate: {default_rate:.2f}%"
)
# Out:
# Default Rate: 22.12%

# %%
print("Mean:", df["AGE"].mean())
print("Median:", df["AGE"].median())
print("Mode:", df["AGE"].mode()[0])
# Out:
# Mean: 35.4855
# Median: 34.0
# Mode: 29

# %%
print("Mean:", df["LIMIT_BAL"].mean())
print("Median:", df["LIMIT_BAL"].median())
# Out:
# Mean: 167484.32266666667
# Median: 140000.0

# %%
print(
    "Variance:",
    df["AGE"].var()
)

print(
    "Std Dev:",
    df["AGE"].std()
)
# Out:
# Variance: 84.96975540851363
# Std Dev: 9.217904068090188

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df["AGE"],
    bins=20,
    kde=True
)

plt.title("Age Distribution")
plt.show()

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df["LIMIT_BAL"],
    bins=30,
    kde=True
)

plt.title("Credit Limit Distribution")
plt.show()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(
    x=df["AGE"]
)

plt.show()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(
    x=df["LIMIT_BAL"]
)

plt.show()

# %%
Q1 = df["LIMIT_BAL"].quantile(0.25)

Q3 = df["LIMIT_BAL"].quantile(0.75)

IQR = Q3 - Q1

# %%
lower = Q1 - (1.5 * IQR)

upper = Q3 + (1.5 * IQR)

# %%
outliers = df[
    (df["LIMIT_BAL"] < lower)
    |
    (df["LIMIT_BAL"] > upper)
]

len(outliers)
# Out:
# 167

# %%
corr = df.corr(
    numeric_only=True
)

# %%
corr.head()
# Out:
#                  ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE  \
# ID         1.000000   0.026179  0.018497   0.039177 -0.029079  0.018678
# LIMIT_BAL  0.026179   1.000000  0.024755  -0.219161 -0.108139  0.144713
# SEX        0.018497   0.024755  1.000000   0.014232 -0.031389 -0.090874
# EDUCATION  0.039177  -0.219161  0.014232   1.000000 -0.143464  0.175061
# MARRIAGE  -0.029079  -0.108139 -0.031389  -0.143464  1.000000 -0.414170
#
#               PAY_0     PAY_2     PAY_3     PAY_4     PAY_5     PAY_6  \
# ID        -0.030575 -0.011215 -0.018494 -0.002735 -0.022199 -0.020270
# LIMIT_BAL -0.271214 -0.296382 -0.286123 -0.267460 -0.249411 -0.235195
# SEX       -0.057643 -0.070771 -0.066096 -0.060173 -0.055064 -0.044008
# EDUCATION  0.105364  0.121566  0.114025  0.108793  0.097520  0.082316
# MARRIAGE   0.019917  0.024199  0.032688  0.033122  0.035629  0.034345
#
#            BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ...

# %%
plt.figure(
    figsize=(18,12)
)

sns.heatmap(
    corr,
    cmap="coolwarm"
)

plt.title(
    "Correlation Heatmap"
)

plt.show()

# %%
corr["DEFAULT"]\
.sort_values(
    ascending=False
)
# Out:
# DEFAULT      1.000000
# PAY_0        0.324794
# PAY_2        0.263551
# PAY_3        0.235253
# PAY_4        0.216614
# PAY_5        0.204149
# PAY_6        0.186866
# EDUCATION    0.028006
# AGE          0.013890
# BILL_AMT6   -0.005372
# BILL_AMT5   -0.006760
# BILL_AMT4   -0.010156
# ID          -0.013952
# BILL_AMT3   -0.014076
# BILL_AMT2   -0.014193
# BILL_AMT1   -0.019644
# MARRIAGE    -0.024339
# SEX         -0.039961
# PAY_AMT6    -0.053183
# PAY_AMT5    -0.055124
# PAY_AMT3    -0.056250
# PAY_AMT4    -0.056827
# PAY_AMT2    -0.058579
# PAY_AMT1    -0.072929
# LIMIT_BAL   -0.153520
# Name: DEFAULT, dtype: float64

# %% [markdown]
# ## Key Insights
#
# 1. Dataset contains 30,000 customers.
#
# 2. Default rate is approximately 22%.
#
# 3. Dataset contains no missing values.
#
# 4. Dataset contains no duplicate records.
#
# 5. Credit limit is right-skewed.
#
# 6. Credit limit contains significant outliers.
#
# 7. Repayment status variables show strongest correlation with default.
